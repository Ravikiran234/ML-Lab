# %%
# 1. Read top five values
import pandas as pd
df=pd.read_csv("/home/user/Downloads/Ml_Lab/Car_sales.csv")
df.head(5)
# Out:
#     Manufacturer              Model  Sales in thousands 4-year resale value  \
# 0  Acura          Integra                        16.919               16.36
# 1  Acura          TL                             39.384              19.875
# 2  Acura          CL                             14.114              18.225
# 3  Acura          RL                              8.588              29.725
# 4  Audi           A4                             20.397              22.255
#
#   Vehicle type Price in thousands Engine size Horsepower Wheelbase Width  \
# 0    Passenger               21.5         1.8        140     101.2  67.3
# 1    Passenger               28.4         3.2        225     108.1  70.3
# 2    Passenger                  .         3.2        225     106.9  70.6
# 3    Passenger                 42         3.5        210     114.6  71.4
# 4    Passenger              23.99         1.8        150     102.6  68.2
#
#   Length Curb weight Fuel capacity Fuel efficiency Latest Launch
# ...

# %%
# 2. Print dataframe info_data types of each column
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 157 entries, 0 to 156
# Data columns (total 15 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Manufacturer         157 non-null    object
#  1   Model                157 non-null    object
#  2   Sales in thousands   157 non-null    float64
#  3   4-year resale value  157 non-null    object
#  4   Vehicle type         157 non-null    object
#  5   Price in thousands   157 non-null    object
#  6   Engine size          157 non-null    object
#  7   Horsepower           157 non-null    object
#  8   Wheelbase            157 non-null    object
#  9   Width                157 non-null    object
#  10  Length               157 non-null    object
#  11  Curb weight          157 non-null    object
#  12  Fuel capacity        157 non-null    object
#  13  Fuel efficiency      157 non-null    object
#  14  Latest Launch        157 non-null    object
# ...

# %%
# 3. Print number of rows and columns
rows=df.shape[0]
columns = df.shape[1]
print("no.of rows:",rows)
print("no.of columns:",columns)
# Out:
# no.of rows: 157
# no.of columns: 15

# %%
# 4. Drop duplicate rows_if any
df.drop_duplicates()
# Out:
#       Manufacturer              Model  Sales in thousands 4-year resale value  \
# 0    Acura          Integra                        16.919               16.36
# 1    Acura          TL                             39.384              19.875
# 2    Acura          CL                             14.114              18.225
# 3    Acura          RL                              8.588              29.725
# 4    Audi           A4                             20.397              22.255
# ..             ...                ...                 ...                 ...
# 152  Volvo          V40                             3.545                   .
# 153  Volvo          S70                            15.245                   .
# 154  Volvo          V70                            17.531                   .
# 155  Volvo          C70                             3.493                   .
# 156  Volvo          S80                            18.969                   .
#
# ...

# %%
# 5. Print number of rows and columns after dropping duplicates
df.shape[0],df.shape[1]
# Out:
# (157, 15)

# %%
# 6. Print summary statistics for numerical variables
df.describe()
# Out:
#        Sales in thousands
# count          157.000000
# mean            52.998076
# std             68.029422
# min              0.110000
# 25%             14.114000
# 50%             29.450000
# 75%             67.956000
# max            540.561000

# %%
# 7. Print number of missing values in each column
df.isnull().sum()
# Out:
# Manufacturer           0
# Model                  0
# Sales in thousands     0
# 4-year resale value    0
# Vehicle type           0
# Price in thousands     0
# Engine size            0
# Horsepower             0
# Wheelbase              0
# Width                  0
# Length                 0
# Curb weight            0
# Fuel capacity          0
# Fuel efficiency        0
# Latest Launch          0
# dtype: int64

# %%
# 8. Drop the column with most missing values
df.isnull().sum().idxmax()
# Out:
# 'Manufacturer'

# %%
# 9. Drop the rows with categorical missing values
rows=df.select_dtypes(include=['object']).columns
df.dropna(subset=rows)
# Out:
#       Manufacturer              Model  Sales in thousands 4-year resale value  \
# 0    Acura          Integra                        16.919               16.36
# 1    Acura          TL                             39.384              19.875
# 2    Acura          CL                             14.114              18.225
# 3    Acura          RL                              8.588              29.725
# 4    Audi           A4                             20.397              22.255
# ..             ...                ...                 ...                 ...
# 152  Volvo          V40                             3.545                   .
# 153  Volvo          S70                            15.245                   .
# 154  Volvo          V70                            17.531                   .
# 155  Volvo          C70                             3.493                   .
# 156  Volvo          S80                            18.969                   .
#
# ...

# %%
# 10. Import the rows with numerical missing values
rows_miss = df.select_dtypes(include=['number']).columns
miss = df[df[rows_miss].isnull().any(axis=1)]
miss
# Out:
# Empty DataFrame
# Columns: [Manufacturer, Model, Sales in thousands, 4-year resale value, Vehicle type, Price in thousands, Engine size, Horsepower, Wheelbase, Width, Length, Curb weight, Fuel capacity, Fuel efficiency, Latest Launch]
# Index: []

# %%
# 11. Sort the data w.r.t price_find the details of the most and the least expensive cars
sort=df.sort_values(by="Price in thousands")
sort.iloc[0]
sort.iloc[-1]
# Out:
# Manufacturer               Hyundai
# Model                  Accent
# Sales in thousands                41.184
# 4-year resale value                 5.86
# Vehicle type                   Passenger
# Price in thousands                 9.699
# Engine size                          1.5
# Horsepower                            92
# Wheelbase                           96.1
# Width                               65.7
# Length                             166.7
# Curb weight                         2.24
# Fuel capacity                       11.9
# Fuel efficiency                       31
# Latest Launch                   9-Oct-14
# Name: 62, dtype: object

# %%
# 12. Write a function to find min and max values of any column

def find_min_max(df,col_name):
    if col_name in df.columns:
     min_value = df[col_name].min()
     max_value = df[col_name].max()
     return min_value,max_value
    else:
     return f"Column '{column_name}' not found in dataset"

Horsepower = find_min_max(df,"Horsepower")

print(Horsepower)
# Out:
# ('.', '92')

# %%
# 13. Call the above function to find min max of horsepower, length, fuel efficiency
horsepower  = find_min_max(df,"Horsepower")
length   = find_min_max(df,"Length")
fuel_efficiency  = find_min_max(df,"Fuel efficiency")

print(horsepower, length, fuel_efficiency)
# Out:
# ('.', '92') ('.', '224.5') ('.', '45')

# %%
# 14. Plot histogram of continuous numerical variable : price,sales,hoursepower,fuelefficiency
import seaborn as sns
import matplotlib.pyplot as plt
columns=['Price in thousands','Sales in thousands','Horsepower','Fuel efficiency']
df[columns] = df[columns].apply(pd.to_numeric, errors='coerce')

for i,col in enumerate(columns,1):
    plt.figure(figsize=(12,8))
    plt.subplot(2,2,i)
    sns.histplot(df[col].dropna(),bins=20,color='skyblue')
    plt.title(f'histogram of:{col}')
    plt.xlabel(col)
    plt.ylabel('Frequency') 
    plt.tight_layout()
    plt.show()

# %%
# 15. Probability density distribution of continuous numerical variable-length
df['Length']=pd.to_numeric(df["Length"],errors="coerce")

sns.kdeplot(df["Length"].dropna(),fill=True,color="blue" )  #dropna just skips the Nan values
plt.title("Probability Density Distribution of Length")  # Set title
plt.xlabel("Length")  # Label x-axis
plt.ylabel("Density")  # Label y-axis

plt.show()

# %%
# 16. Count by category –group by manufacture
df.groupby('Manufacturer')['Manufacturer'].count()
# Out:
# Manufacturer
# Acura             4
# Audi              3
# BMW               3
# Buick             4
# Cadillac          5
# Chevrolet         9
# Chrysler          7
# Dodge            11
# Ford             11
# Honda             5
# Hyundai           3
# Infiniti          1
# Jaguar            1
# Jeep              3
# Lexus             6
# Lincoln           3
# Mercedes-Benz     9
# Mercury           6
# Mitsubishi        7
# Nissan            7
# Oldsmobile        6
# Plymouth          4
# Pontiac           6
# Porsche           3
# Saab              2
# Saturn            5
# Subaru            2
# Toyota            9
# Volkswagen        6
# Volvo             6
# Name: Manufacturer, dtype: int64

# %%
df['Manufacturer'].value_counts()
# Out:
# Manufacturer
# Ford             11
# Dodge            11
# Chevrolet         9
# Toyota            9
# Mercedes-Benz     9
# Chrysler          7
# Nissan            7
# Mitsubishi        7
# Volvo             6
# Volkswagen        6
# Oldsmobile        6
# Pontiac           6
# Mercury           6
# Lexus             6
# Honda             5
# Saturn            5
# Cadillac          5
# Plymouth          4
# Acura             4
# Buick             4
# Jeep              3
# Hyundai           3
# Porsche           3
# Lincoln           3
# Audi              3
# BMW               3
# Saab              2
# Subaru            2
# Infiniti          1
# Jaguar            1
# Name: count, dtype: int64

# %%
# 17. Select all numerical variables
numeric_val = df.select_dtypes(include=['number'])
numeric_val
# Out:
#      Sales in thousands  Price in thousands  Horsepower  Length  \
# 2                14.114                 NaN       225.0   192.0
# 33               53.480                 NaN         NaN     NaN
# 129              80.620              10.685       100.0   176.9
# 140              84.087              11.528       142.0   178.7
# 63               66.692              11.799       140.0   174.0
# ..                  ...                 ...         ...     ...
# 126               1.866              74.970       300.0   174.5
# 95                3.311              82.600       302.0   177.1
# 99                0.954              85.500       302.0   196.6
# 26               21.855               9.235        55.0   149.4
# 62               41.184               9.699        92.0   166.7
#
#      Fuel efficiency
# 2               26.0
# 33               NaN
# 129             33.0
# 140             23.0
# 63              27.0
# ..               ...
# 126             23.0
# ...

# %%
# 18. Print correlation coefficient value of price and sales
corr_coef=df['Price in thousands'].corr(df['Sales in thousands'])
# Out:
# -0.3047344541294121

# %%
# 19. Plot correlation of price and sales using scatterplot
# Scatterplot of Price vs Sales
sns.scatterplot(data=df, x='Price in thousands', y='Sales in thousands')

# Optional: Add title and labels
plt.title('Correlation between Price and Sales')
plt.xlabel('Price')
plt.ylabel('Sales')

plt.show()

# %%
# 20.Pair plot
columns = df.select_dtypes(include=['number'])
sns.pairplot(columns)
plt.show()

# %%
# 21. Boxplot of sales of different manufacturer
plt.figure(figsize=(8, 5))
sns.boxplot(x=df["Manufacturer"], y=df["Sales in thousands"])
# Customize labels
plt.xlabel("Manufacturer")
plt.ylabel("Sales")
plt.title("Sales Distribution by Manufacturer")
plt.show()

# %%
# 22. Boxplot of other numerical variables w.r.t manufacture
columns = df.select_dtypes(include=['number']).columns
for col in columns:
    plt.figure(figsize=(12,8))
    sns.boxplot(x=df['Manufacturer'],y=df[col],data=df)
    plt.title(f'boxplot of Manufacture and {col}')
    plt.xlabel("Manufacturer")
    plt.ylabel(f'{col}')
   
    plt.grid()
    plt.show()

# %%
# 23. Divide the data into input and output y=sales in thousand, x=all other variables
# x=df.drop(columns=['Sales in thousands'])
y=df["Price in thousands"]
x=df.drop(columns=["Price in thousands"])

# %%
# 24. Encode other categorical variables using label encoder
from sklearn.preprocessing import LabelEncoder 
columns = df.select_dtypes(include=['object']).columns
label_encoder={}
for col in columns:
     le = LabelEncoder()
     df[col]=le.fit_transform(df[col])
     label_encoder[col]=le


    print(df.head())
# Out:
# Index([], dtype='object')

# %%
# 25. Encode categorical variable vehicle type using one-hot encoder

df = pd.get_dummies(df, columns=['Vehicle type'], drop_first=True).fillna(0).astype(int)

# %%
# 26.Split the data set into train and test set 70% train set 10% test set
from sklearn.model_selection import train_test_split
x_train,x_remain,y_train,y_remain=train_test_split(x,y,test_size=0.3,random_state=42)
x_vali,x_test,y_vali,y_test=train_test_split(x_remain,y_remain,test_size=2/3,random_state=42)

x_test
# Out:
#       Manufacturer              Model 4-year resale value Vehicle type  \
# 76   Lincoln        Continental                    20.525    Passenger
# 31   Chrysler       Cirrus                          12.64    Passenger
# 45   Dodge          Caravan                        12.025          Car
# 6    Audi           A8                                 39    Passenger
# 142  Toyota         RAV4                           13.325          Car
# 132  Saturn         LW                                  .    Passenger
# 25   Chevrolet      Prizm                           9.125    Passenger
# 68   Jeep           Cherokee                       13.775          Car
# 70   Lexus          ES300                          26.975    Passenger
# 109  Oldsmobile     Intrigue                            .    Passenger
# 103  Nissan         Maxima                         15.125    Passenger
# 77   Lincoln        Town car                       21.725    Passenger
# ...

# %%
# 27. Apply feature scaling on numerical variables
from sklearn.preprocessing import StandardScaler, MinMaxScaler

# Select numerical columns only
numerical_cols = df.select_dtypes(include=['number']).columns

# Choose scaling method (uncomment one)
scaler = StandardScaler()  # Standardization
# scaler = MinMaxScaler()  # Min-Max Scaling

# Apply scaling
df[numerical_cols] = scaler.fit_transform(df[numerical_cols])

# Print the first few rows after scaling
print(df.head())
# Out:
#     Manufacturer              Model  Sales in thousands 4-year resale value  \
# 0  Acura          Integra                     -0.532042               16.36
# 1  Acura          TL                          -0.200761              19.875
# 2  Acura          CL                          -0.573406              18.225
# 3  Acura          RL                          -0.654896              29.725
# 4  Audi           A4                          -0.480754              22.255
#
#   Vehicle type Price in thousands Engine size Horsepower Wheelbase Width  \
# 0    Passenger               21.5         1.8        140     101.2  67.3
# 1    Passenger               28.4         3.2        225     108.1  70.3
# 2    Passenger                  .         3.2        225     106.9  70.6
# 3    Passenger                 42         3.5        210     114.6  71.4
# 4    Passenger              23.99         1.8        150     102.6  68.2
#
#      Length Curb weight Fuel capacity Fuel efficiency Latest Launch
# ...
